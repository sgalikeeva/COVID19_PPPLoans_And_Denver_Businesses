# %%
import pandas as pd

# %%
PPP_loans=pd.read_csv(r"C:\Users\vowel\Downloads\public_150k_plus_220403.csv")
PPP_loans.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9547507704   05/01/2020            464              PPP
# 1  9777677704   05/01/2020            464              PPP
# 2  5791407702   05/01/2020           1013              PPP
# 3  6223567700   05/01/2020            920              PPP
# 4  9662437702   05/01/2020            101              PPP
#
#                BorrowerName        BorrowerAddress      BorrowerCity  \
# 0     SUMTER COATINGS, INC.  2410 Highway 15 South            Sumter
# 1     PLEASANT PLACES, INC.    7684 Southrail Road  North Charleston
# 2   BOYER CHILDREN'S CLINIC       1850 BOYER AVE E           SEATTLE
# 3  KIRTLEY CONSTRUCTION INC   1661 MARTIN RANCH RD    SAN BERNARDINO
# 4              AERO BOX LLC                    NaN               NaN
#
#   BorrowerState BorrowerZip LoanStatusDate  ...             BusinessType  \
# 0           NaN  29150-9662     12/18/2020  ...              Corporation
# ...

# %%
PPP_loans.shape
# Out:
# (968532, 53)

# %%
PPP_loans_step1 = PPP_loans.loc[(PPP_loans.BorrowerCity =="Denver")& (PPP_loans.BorrowerState == "CO")]
PPP_loans_step1.head()
# Out:
#         LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 165883  8590487004   04/08/2020            811              PPP
# 165887  9596397007   04/09/2020            811              PPP
# 165894  1667347201   04/15/2020            811              PPP
# 165960  4971537306   04/30/2020            811              PPP
# 165984  6162597203   04/27/2020            811              PPP
#
#                     BorrowerName                      BorrowerAddress  \
# 165883  SNOOZE IMPORT EXPORT LLC    3001 Brighton Blvd, Suite 303 0.0
# 165887        PBS BRAND CO., LLC          3120 N Uinta St Ste 300 0.0
# 165894             WELLTOK, INC.  1515 Arapahoe St Tower 3, Suite 700
# 165960    SULLIVAN'S HOLDING LLC              1855 Blake St Suite 200
# 165984    FRAC SHACK AMERICA INC        999 18th Street, Suite 3400 S
#
#        BorrowerCity BorrowerState BorrowerZip LoanStatusDate  ...  \
# 165883       Denver            CO  80216-5082     07/22/2021  ...
# ...

# %%
PPP_loans_step1.shape
# Out:
# (2031, 53)
