# %%
import pandas as pd
import numpy as np

# %%
PPP_df = pd.read_csv(r"C:\Users\vowel\Desktop\PPP_df.csv")
NAICS_df = pd.read_csv(r"C:\Users\vowel\Downloads\6-digit_2022_Codes.csv")

# %%
PPP_df.head()
# Out:
#    LoanNumber DateApproved                     BorrowerName  \
# 0  4069407308   04/29/2020               KAVKAZ EXPRESS LLC
# 1  4923917101   04/13/2020       SOUTHWESTERN PROPERTY CORP
# 2  1207727109   04/10/2020   ARM DATA CENTER SERVICES, INC.
# 3  4436977209   04/27/2020       S & S RESTAURANT GROUP INC
# 4  8556267004   04/08/2020  VOLUNTEERS FOR OUTDOOR COLORADO
#
#                BorrowerAddress BorrowerZip LoanStatusDate    LoanStatus  Term  \
# 0            8051 E BAYAUD AVE  80230-6748     09/24/2021  Paid in Full    24
# 1  7979 E Tufts Ave Suite 1125  80237-2521     04/08/2021  Paid in Full    24
# 2              1550 Wewatta St  80202-6159     07/20/2021  Paid in Full    24
# 3         92 S PENNSYLVANIA ST       80209     03/11/2021  Paid in Full    24
# 4         600 S Marion Parkway  80209-2597     03/19/2021  Paid in Full    24
#
#    InitialApprovalAmount  CurrentApprovalAmount  ...     CD JobsReported  \
# ...

# %%
NAICS_df.head()
# Out:
#    2022 NAICS Code                   2022 NAICS Title Unnamed: 2
# 0              NaN                                NaN        NaN
# 1         111110.0                    Soybean Farming        NaN
# 2         111120.0  Oilseed (except Soybean) Farming         NaN
# 3         111130.0          Dry Pea and Bean Farming         NaN
# 4         111140.0                      Wheat Farming        NaN

# %%
sorted_ppp_df = PPP_df.sort_values(by='CurrentApprovalAmount', ascending=False)
sorted_ppp_df.head(50)
# Out:
#        LoanNumber DateApproved                             BorrowerName  \
# 11194  2453537209   04/16/2020         SERVICE SYSTEMS ASSOCIATES, INC.
# 11195  3541737204   04/27/2020            THE WESTERN SUGAR COOPERATIVE
# 11196  4483637106   04/13/2020           OMNITRAX HOLDINGS COMBINED INC
# 11197  8013527003   04/08/2020                   ALVARADO CONCEPTS, LLC
# 11198  8578657102   04/15/2020                      MAC ACQUISITION LLC
# 11199  8963577000   04/09/2020                    INTREPID POTASH, INC.
# 11200  6908527201   04/28/2020                        THE ONE GROUP LLC
# 11201  8672097009   04/08/2020                           INSPIRATO, LLC
# 11202  6842337210   04/28/2020              KONA GRILL ACQUISITION, LLC
# 11203  2441517108   04/10/2020             PERFX WIRELINE SERVICES, LLC
# 11204  5061397100   04/13/2020  BIGHORN CONSTRUCTION & RECLAMATION, LLC
# 11205  8728957203   04/28/2020                       INTELLISOURCE, LLC
# ...

# %%
sorted_ppp_df.dtypes
# Out:
# LoanNumber                  int64
# DateApproved               object
# BorrowerName               object
# BorrowerAddress            object
# BorrowerZip                object
# LoanStatusDate             object
# LoanStatus                 object
# Term                        int64
# InitialApprovalAmount     float64
# CurrentApprovalAmount     float64
# UndisbursedAmount         float64
# RuralUrbanIndicator        object
# BusinessAgeDescription     object
# CD                         object
# JobsReported              float64
# NAICSCode                 float64
# Race                       object
# Ethnicity                  object
# BusinessType               object
# Gender                     object
# Veteran                    object
# ForgivenessAmount         float64
# ForgivenessDate            object
# dtype: object

# %%
sorted_ppp_df.dropna()
# Out:
#        LoanNumber DateApproved                      BorrowerName  \
# 11194  2453537209   04/16/2020  SERVICE SYSTEMS ASSOCIATES, INC.
# 11195  3541737204   04/27/2020     THE WESTERN SUGAR COOPERATIVE
# 11197  8013527003   04/08/2020            ALVARADO CONCEPTS, LLC
# 11199  8963577000   04/09/2020             INTREPID POTASH, INC.
# 11200  6908527201   04/28/2020                 THE ONE GROUP LLC
# ...           ...          ...                               ...
# 11188  1561598106   07/10/2020                        JR FLEMING
# 11189  4822128206   08/06/2020             WHITE KNIGHT ELECTRIC
# 11190  9957677309   05/03/2020          CROSSCOURT SOLUTIONS LLC
# 11192  1261138400   02/01/2021                     SONYA VALADEZ
# 11193  6055548004   06/29/2020              TRANSCEND DENVER LLC
#
#                        BorrowerAddress BorrowerZip LoanStatusDate  \
# 11194           4624 CENTRAL PARK BLVD  80238-2328     07/17/2021
# ...

# %%
PPP_NAICS_df=PPP_df.merge(NAICS_df, left_on='NAICSCode', right_on="2022 NAICS Code")
PPP_NAICS_df = PPP_NAICS_df.loc[:,~PPP_NAICS_df.columns.str.contains('^Unnamed')]
PPP_NAICS_df.head(100)
# Out:
#     LoanNumber DateApproved                        BorrowerName  \
# 0   4069407308   04/29/2020                  KAVKAZ EXPRESS LLC
# 1   3546587108   04/11/2020           BACK TO BACK TRUCKING LLC
# 2   7412657108   04/14/2020       COLORADO ATLANTIC EXPRESS LLC
# 3   2990007100   04/11/2020  ROCKY MOUNTAIN DATA SERVICES, INC.
# 4   6266777410   05/14/2020                  EASTLEIGH TRUCKING
# ..         ...          ...                                 ...
# 95  1207727109   04/10/2020      ARM DATA CENTER SERVICES, INC.
# 96  8344677704   05/01/2020            PRECISION MANAGEMENT LLC
# 97  2179838306   01/20/2021            GLOBAL ASSESSOR POOL LLC
# 98  7693317008   04/08/2020       THE WELLS PARTNERSHIP COMPANY
# 99  4759077705   05/01/2020                           WDHB INC.
#
#                        BorrowerAddress BorrowerZip LoanStatusDate  \
# 0                    8051 E BAYAUD AVE  80230-6748     09/24/2021
# ...

# %%
PPP_NAICS_df.to_csv(r"C:\Users\vowel\Desktop\PPP_NAICS_df.csv", index=False)

# %%
sorted_merged_ppp = PPP_NAICS_df.sort_values(by='CurrentApprovalAmount', ascending=False)
sorted_merged_ppp
# Out:
#        LoanNumber DateApproved                      BorrowerName  \
# 12054  4483637106   04/13/2020    OMNITRAX HOLDINGS COMBINED INC
# 1519   8578657102   04/15/2020               MAC ACQUISITION LLC
# 452    8013527003   04/08/2020            ALVARADO CONCEPTS, LLC
# 7769   2453537209   04/16/2020  SERVICE SYSTEMS ASSOCIATES, INC.
# 12053  3541737204   04/27/2020     THE WESTERN SUGAR COOPERATIVE
# ...           ...          ...                               ...
# 6574   4822128206   08/06/2020             WHITE KNIGHT ELECTRIC
# 10051  9957677309   05/03/2020          CROSSCOURT SOLUTIONS LLC
# 7331   5255128105   07/18/2020    AREA NETWORK TRANSPORT SERVICE
# 12006  1261138400   02/01/2021                     SONYA VALADEZ
# 6974   6055548004   06/29/2020              TRANSCEND DENVER LLC
#
#                        BorrowerAddress BorrowerZip LoanStatusDate  \
# 12054                   252 CLAYTON ST  80206-4800            NaN
# ...

# %%
TOP_100_PPP=sorted_merged_ppp.head(100)
TOP_100_PPP
# Out:
#        LoanNumber DateApproved                       BorrowerName  \
# 12054  4483637106   04/13/2020     OMNITRAX HOLDINGS COMBINED INC
# 1519   8578657102   04/15/2020                MAC ACQUISITION LLC
# 452    8013527003   04/08/2020             ALVARADO CONCEPTS, LLC
# 7769   2453537209   04/16/2020   SERVICE SYSTEMS ASSOCIATES, INC.
# 12053  3541737204   04/27/2020      THE WESTERN SUGAR COOPERATIVE
# ...           ...          ...                                ...
# 11832  8250687303   05/01/2020    EVERGREEN NATURAL RESOURCES LLC
# 12062  2851587306   04/29/2020  READY MIXED CONCRETE COMPANY, LLC
# 10864  4905037006   04/04/2020         PRIME WINDOWS SYSTEMS, LLC
# 6673   5751977007   04/06/2020           YEH AND ASSOCIATES, INC.
# 9350   7665167003   04/07/2020         K.P. KAUFFMAN COMPANY, INC
#
#                      BorrowerAddress BorrowerZip LoanStatusDate    LoanStatus  \
# 12054                 252 CLAYTON ST  80206-4800            NaN   Exemption 4
# ...

# %%
GENERAL_TOP_100_DF = TOP_100_PPP.merge(General_Categories_df, left_on='NAICSCode', right_on="NAICS_CODE")
GENERAL_TOP_100_DF
# Out:
#     LoanNumber DateApproved                               BorrowerName  \
# 0   4483637106   04/13/2020             OMNITRAX HOLDINGS COMBINED INC
# 1   8578657102   04/15/2020                        MAC ACQUISITION LLC
# 2   6908527201   04/28/2020                          THE ONE GROUP LLC
# 3   1915817102   04/10/2020                             MODMARKET, LLC
# 4   7752467302   04/30/2020          MAC ACQUISITION OF NEW JERSEY LLC
# ..         ...          ...                                        ...
# 95  6654037108   04/14/2020                  DANA KEPNER COMPANY, INC.
# 96  5958267210   04/27/2020  ROCKY MOUNTAIN SER JOBS FOR PROGRESS, INC
# 97  8250687303   05/01/2020            EVERGREEN NATURAL RESOURCES LLC
# 98  4905037006   04/04/2020                 PRIME WINDOWS SYSTEMS, LLC
# 99  7665167003   04/07/2020                 K.P. KAUFFMAN COMPANY, INC
#
#              BorrowerAddress BorrowerZip LoanStatusDate    LoanStatus  Term  \
# ...

# %%
TOP_100_PPP.to_csv(r"C:\Users\vowel\Desktop\TOP_100_PPP.csv", index=False)

# %%
General_Categories_df = pd.read_csv(r"C:\Users\vowel\Downloads\General NAICS Categories.csv")
General_Categories_df = General_Categories_df.loc[:,~General_Categories_df.columns.str.contains('^Unnamed')]
General_Categories_df.dtypes
# Out:
# NAICS_CODE              int64
# 2022 NAICS US Title    object
# General Category       object
# dtype: object

# %%
General_Categories_df["NAICS_CODE"]=General_Categories_df["NAICS_CODE"].astype(float)

# %%
PPP_NAICS_df.dtypes
# Out:
# LoanNumber                  int64
# DateApproved               object
# BorrowerName               object
# BorrowerAddress            object
# BorrowerZip                object
# LoanStatusDate             object
# LoanStatus                 object
# Term                        int64
# InitialApprovalAmount     float64
# CurrentApprovalAmount     float64
# UndisbursedAmount         float64
# RuralUrbanIndicator        object
# BusinessAgeDescription     object
# CD                         object
# JobsReported              float64
# NAICSCode                 float64
# Race                       object
# Ethnicity                  object
# BusinessType               object
# Gender                     object
# Veteran                    object
# ForgivenessAmount         float64
# ForgivenessDate            object
# 2022 NAICS Code           float64
# 2022 NAICS Title           object
# dtype: object

# %%
PPP_GENERAL_DF=PPP_df.merge(General_Categories_df, left_on='NAICSCode', right_on="NAICS_CODE")
PPP_GENERAL_DF
# Out:
#        LoanNumber DateApproved  \
# 0      4069407308   04/29/2020
# 1      3546587108   04/11/2020
# 2      7412657108   04/14/2020
# 3      2990007100   04/11/2020
# 4      6266777410   05/14/2020
# ...           ...          ...
# 11779  3206247300   04/29/2020
# 11780  4103267700   05/01/2020
# 11781  8634827002   04/08/2020
# 11782  6154927206   04/27/2020
# 11783  6523837003   04/07/2020
#
#                                           BorrowerName  \
# 0                                   KAVKAZ EXPRESS LLC
# 1                            BACK TO BACK TRUCKING LLC
# 2                        COLORADO ATLANTIC EXPRESS LLC
# 3                   ROCKY MOUNTAIN DATA SERVICES, INC.
# 4                                   EASTLEIGH TRUCKING
# ...                                                ...
# 11779  THE EARLY CHILDHOOD PARTNERSHIP OF ADAMS COUNTY
# 11780                        GALILEO SYSTEMS GROUP INC
# 11781                              DENVER BIKE SHARING
# ...

# %%
PPP_GENERAL_DF.to_csv(r"C:\Users\vowel\Desktop\PPP_GENERAL_DF.csv", index=False)

# %%
TOTAL_PPP_GENERAL_DF = sorted_merged_ppp.merge(General_Categories_df, left_on='NAICSCode', right_on="NAICS_CODE")
TOTAL_PPP_GENERAL_DF
# Out:
#        LoanNumber DateApproved                       BorrowerName  \
# 0      4483637106   04/13/2020     OMNITRAX HOLDINGS COMBINED INC
# 1      8578657102   04/15/2020                MAC ACQUISITION LLC
# 2      6908527201   04/28/2020                  THE ONE GROUP LLC
# 3      1915817102   04/10/2020                     MODMARKET, LLC
# 4      7752467302   04/30/2020  MAC ACQUISITION OF NEW JERSEY LLC
# ...           ...          ...                                ...
# 11779  5098157309   04/30/2020               SV GUIDING LIGHT LLC
# 11780  9079077410   05/19/2020                    WISDOM WORMENOR
# 11781  6923718008   06/30/2020                BIOGEST AMERICA INC
# 11782  7417917810   06/03/2020             BIOCOTECH AMERICAS LLC
# 11783  3995967404   05/08/2020          TIGER TOOTH MARKETING LLC
#
#                    BorrowerAddress BorrowerZip LoanStatusDate    LoanStatus  \
# 0                   252 CLAYTON ST  80206-4800            NaN   Exemption 4
# ...

# %%
TOTAL_PPP_GENERAL_DF.to_csv(r"C:\Users\vowel\Desktop\TOTAL_PPP_GENERAL_DF.csv", index=False)
GENERAL_TOP_100_DF.to_csv(r"C:\Users\vowel\Desktop\GENERAL_TOP_100_DF.csv", index=False)
