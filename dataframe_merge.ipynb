# %%
import pandas as pd
import geopy.distance

# %%
pip install geopy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
auto_part_theft = pd.read_csv(r"C:\Users\vowel\Desktop\auto_part_theft.csv")
auto_part_theft.head()
# Out:
#    incident_id    offense_id  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0     20223421  2.022340e+13          2304                       0
# 1  20226000117  2.022600e+16          2304                       0
# 2     20226673  2.022670e+13          2304                       0
# 3     20228679  2.022870e+13          2304                       0
# 4     20225711  2.022570e+13          2304                       0
#
#             OFFENSE_TYPE_ID       OFFENSE_CATEGORY_ID FIRST_OCCURRENCE_DATE  \
# 0  theft-parts-from-vehicle  theft-from-motor-vehicle         1/3/2022 0:00
# 1  theft-parts-from-vehicle  theft-from-motor-vehicle         1/3/2022 0:20
# 2  theft-parts-from-vehicle  theft-from-motor-vehicle        1/4/2022 18:00
# 3  theft-parts-from-vehicle  theft-from-motor-vehicle        1/2/2022 22:00
# 4  theft-parts-from-vehicle  theft-from-motor-vehicle         1/4/2022 6:40
#
#   LAST_OCCURRENCE_DATE   REPORTED_DATE  \
# 0                  NaN  1/3/2022 10:47
# ...

# %%
auto_repair = pd.read_csv(r"C:\Users\vowel\Desktop\auto_repair.csv")
auto_repair.head()
# Out:
#    Unnamed: 0                       name         phone  \
# 0           0        Strictly Automotive  1.303436e+10
# 1           1     Les Schwab Tire Center  1.303456e+10
# 2           2  Golden Triangle Auto Care  1.303573e+10
# 3           3            Paddock Imports  1.303826e+10
# 4           4              Auto Know How  1.303892e+10
#
#                                address  \
# 0     804 W 10th Ave  Denver, CO 80204
# 1  2001 Federal Blvd  Denver, CO 80211
# 2    1112 Speer Blvd  Denver, CO 80204
# 3     2400 W 7th Ave  Denver, CO 80204
# 4   1240 Umatilla St  Denver, CO 80204
#
#                                 category_alias  \
# 0                 autorepair, usedcardealers,
# 1               tires, autorepair, oilchange,
# 2  autorepair, oilchange, transmissionrepair,
# 3       autorepair, autopartssupplies, tires,
# 4                                 autorepair,
#
#                                       category_title  rating  review_count  \
# ...

# %%
columns = ["FIRST_OCCURRENCE_DATE","LAST_OCCURRENCE_DATE","DISTRICT_ID", "PRECINCT_ID"]

# %%
auto_part_theft.drop(columns, axis=1, inplace=True)
auto

# %%
auto_part_theft.head()
# Out:
#    incident_id    offense_id  OFFENSE_CODE  OFFENSE_CODE_EXTENSION  \
# 0     20223421  2.022340e+13          2304                       0
# 1  20226000117  2.022600e+16          2304                       0
# 2     20226673  2.022670e+13          2304                       0
# 3     20228679  2.022870e+13          2304                       0
# 4     20225711  2.022570e+13          2304                       0
#
#             OFFENSE_TYPE_ID       OFFENSE_CATEGORY_ID   REPORTED_DATE  \
# 0  theft-parts-from-vehicle  theft-from-motor-vehicle  1/3/2022 10:47
# 1  theft-parts-from-vehicle  theft-from-motor-vehicle  1/3/2022 14:32
# 2  theft-parts-from-vehicle  theft-from-motor-vehicle  1/5/2022 11:26
# 3  theft-parts-from-vehicle  theft-from-motor-vehicle  1/6/2022 16:54
# 4  theft-parts-from-vehicle  theft-from-motor-vehicle  1/4/2022 19:15
#
#                                              address    GEO_X    GEO_Y  \
# ...

# %%
coords_1 = (39.731800, -104.997910)
coords_2 = (39.773534, -104.939033)

print (geopy.distance.distance(coords_1, coords_2).km)
# Out:
# 6.850674051338166
