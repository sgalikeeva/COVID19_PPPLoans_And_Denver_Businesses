# %%
import pandas as pd
import numpy as np

# %%
loans_df = pd.read_csv(r"C:\Users\vowel\Downloads\loans_df(1).csv", index_col=[0])
loans_df.head()
# Out:
#    LoanNumber DateApproved                BorrowerName  \
# 0  8728957203    4/28/2020               INTELLISOURCE
# 1  8681407204    4/28/2020        PRIMESOURCE STAFFING
# 2  9826177105    4/15/2020               ALLY PRODUCTS
# 3  2089597208    4/15/2020   DAVIS GRAHAM & STUBBS LLP
# 4  8574487102    4/15/2020  ORTHOPEDIC CENTERS OFORADO
#
#                   BorrowerAddress  BorrowerZip LoanStatusDate    LoanStatus  \
# 0        1899 Wynkoop St, Ste 200        80202      6/17/2021  Paid in Full
# 1  10065 E Harvard Ave, Suite 230        80231      7/20/2021  Paid in Full
# 2                 1635 W 13TH AVE        80204      9/28/2021  Paid in Full
# 3       1550 17th Street, Ste 500        80202      7/13/2021  Paid in Full
# 4                 8101 LOWRY BLVD        80230      9/25/2021  Paid in Full
#
#    Term  InitialApprovalAmount  CurrentApprovalAmount  ...        Gender  \
# 0    24             7275742.00             7275742.00  ...  Female Owned
# ...
